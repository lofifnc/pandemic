# %%
from pandemic.learning.environment import PandemicEnvironment
from pandemic.learning.transition import ReplayMemory
from pandemic.learning.transition import Transition
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from itertools import count

import torch
import torch.nn as nn
import torch.nn.functional as F


env = PandemicEnvironment(num_epidemic_cards=4, characters=(5,7))

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def net(n_in, n_out, n_h):
    return nn.Sequential(nn.Linear(n_in, n_h),
                     nn.ReLU(),
                     nn.Linear(n_h, n_out),
                     nn.Sigmoid())

# %%
class DQN(nn.Module):

    def __init__(self, inputs, outputs):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=5, stride=2)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=5, stride=2)
        self.bn2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=5, stride=2)
        self.bn3 = nn.BatchNorm2d(32)

        # I don't know what a fucking conv net is...
        linear_input_size = inputs
        self.head = nn.Linear(linear_input_size, outputs)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        return self.head(x.view(x.size(0), -1))

# %%
BATCH_SIZE = 128
EPS_START = 0.9
EPS_END = \
    0.05
EPS_DECAY = 20000
TARGET_UPDATE = 10
GAMMA = 0.999


# Get number of actions from gym action space
action_space_dim = env.action_space.shape[0]

# no screen
obs_space_dim = env.observation_space.shape[0] + action_space_dim



policy_net = net(obs_space_dim, action_space_dim, 1000).to(device)
target_net = net(obs_space_dim, action_space_dim, 1000).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = torch.optim.SGD(policy_net.parameters(), lr=0.01)
memory = ReplayMemory(10000)


steps_done = 0

def random_action(action_space):
    idx_nonzero = np.nonzero(action_space)[0]
    return np.random.choice(idx_nonzero)

def select_action(state, action_space):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            policy_out = policy_net(state)
            return policy_out.max(1)[1].view(1, 1)
    else:
        # select random non zero value from action space
        return torch.tensor([[random_action(action_space)]], device=device, dtype=torch.long)


episode_durations = []


def plot_durations():
    plt.figure(2)
    plt.clf()
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # Take 100 episode averages and plot them too
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated
#     if is_ipython:
#         display.clear_output(wait=True)
#         display.display(plt.gcf())

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1)[0].
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # Compute the expected Q values
    expected_state_action_values = (next_state_values) + reward_batch

    # Compute Huber loss
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    # maybe not
#     for param in policy_net.parameters():
#         param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
num_episodes = 1000
for i_episode in range(num_episodes):
    # Initialize the environment and state
    env.reset()
    state = torch.from_numpy(np.concatenate((env.observation_space, env.action_space), axis=None)).float().view(1,obs_space_dim)
    for t in count():
        # Select and perform an action
        action = select_action(state, env.action_space)
        _, reward, done, _ = env.step(action.item())
        reward = torch.tensor([reward], device=device).float()

        # Observe new state
        if not done:
            next_state = torch.from_numpy(np.concatenate((env.observation_space, env.action_space), axis=None)).float().view(1,obs_space_dim)
        else:
            print("reward: ", reward)
            next_state = None

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        # Perform one step of the optimization (on the target network)
        optimize_model()
        if done:
            episode_durations.append(t + 1)
            env.render()
            plot_durations()
            break
    # Update the target network, copying all weights and biases in DQN
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print('Complete')
env.render()
env.close()
# Out:
# DriveFerry(player=5, destination=10)
# 0.019002241994572455
# DriveFerry(player=5, destination=2)
# 0.020002241994572456
# DirectFlight(player=5, destination=4)
# 0.021002241994572454
# DriveFerry(player=5, destination=9)
# 0.022002241994572454
# 0.022002241994572454
# 0.022002241994572454
# OneQuietNight(player=5)
# 0.023002241994572455
# DirectFlight(player=7, destination=42)
# 0.019911100113437767
# DirectFlight(player=7, destination=22)
# 0.020911100113437768
# DriveFerry(player=7, destination=19)
# 0.02191110011343777
# DriveFerry(player=7, destination=8)
# 0.02291110011343777
# 0.02291110011343777
# 0.02291110011343777
# 0.02291110011343777
# 0.02291110011343777
# DirectFlight(player=5, destination=39)
# 0.02391110011343777
# DirectFlight(player=5, destination=12)
# 0.017955550056718884
# DriveFerry(player=5, destination=30)
# 0.018955550056718885
# DirectFlight(player=5, destination=47)
# 0.019955550056718886
# 0.019955550056718886
# ResilientPopulation(player=5, discard_city=48)
# 0.020955550056718883
# 0.020955550056718883
# 0.020955550056718883
# TreatDisease(city=8, target_virus=4)
# 0.021955550056718884
# DriveFerry(player=7, destination=3)
# 0.022955550056718885
# DriveFerry(player=7, destination=46)
# 0.023955550056718886
# DirectFlight(player=7, destination=3)
# 0.024955550056718886
# 0.024955550056718886
# 0.024955550056718886
# GovernmentGrant(player=7, target_city=8)
# 0.025955550056718884
# 0.025955550056718884
# DriveFerry(player=5, destination=42)
# 0.026955550056718885
# DriveFerry(player=5, destination=5)
# 0.027955550056718886
# DriveFerry(player=5, destination=42)
# 0.028955550056718883
# DriveFerry(player=5, destination=14)
# 0.029955550056718884
# 0.029955550056718884
# 0.03691110011343777
# 0.03691110011343777
# 0.03691110011343777
# DriveFerry(player=7, destination=18)
# 0.03791110011343777
# DriveFerry(player=7, destination=11)
# 0.03891110011343777
# DirectFlight(player=7, destination=48)
# 0.03991110011343777
# DriveFerry(player=7, destination=2)
# 0.040911100113437765
# epidemic!!!
# 0.040911100113437765
# 0.040911100113437765
# 0.040911100113437765
# 0.040911100113437765
# outbreak
# -0.08408889988656224
# DirectFlight(player=5, destination=11)
# -0.09004444994328112
# DriveFerry(player=5, destination=18)
# -0.08904444994328112
# DirectFlight(player=5, destination=8)
# -0.08804444994328112
# DriveFerry(player=5, destination=15)
# -0.08704444994328112
# -0.08008889988656223
# -0.08008889988656223
# -0.08008889988656223
# outbreak
# -0.20508889988656223
# DriveFerry(player=7, destination=48)
# -0.20408889988656223
# DirectFlight(player=7, destination=37)
# -0.20308889988656223
# DriveFerry(player=7, destination=8)
# -0.20208889988656223
# DriveFerry(player=7, destination=19)
# -0.20108889988656223
# -0.19413334982984334
# -0.19004220794870866
# -0.19004220794870866
# -0.19004220794870866
# DirectFlight(player=5, destination=30)
# -0.19599775800542754
# DirectFlight(player=5, destination=26)
# -0.19499775800542754
# DirectFlight(player=5, destination=21)
# -0.19399775800542754
# DriveFerry(player=5, destination=9)
# -0.19299775800542754
# epidemic!!!
# outbreak
# outbreak
# outbreak
# -0.44299775800542757
# -0.44299775800542757
# -0.44299775800542757
# -0.44299775800542757
# -0.44299775800542757
# CharterFlight(player=7, destination=9)
# -0.44895330806214645
# DirectFlight(player=7, destination=13)
# -0.45204444994328113
# DirectFlight(player=7, destination=45)
# -0.458
# DirectFlight(player=7, destination=6)
# -0.457
# -0.45004444994328113
# -0.45004444994328113
# outbreak
# outbreak
# outbreak
# outbreak
# outbreak
# outbreak
# outbreak
# -0.8250444499432811
# reward:  tensor([-0.8250])
# steps:  43
# illegal actions:  13
# cures:  {3: False, 4: False, 1: False, 2: False}
# outbreaks:  7
# Airlift(player=5, target_player=5, destination=28)
# 0.021866650170156654
# DriveFerry(player=5, destination=25)
# 0.022866650170156655
# DriveFerry(player=5, destination=28)
# 0.023866650170156652
# DriveFerry(player=5, destination=29)
# 0.024866650170156653
# DirectFlight(player=5, destination=35)
# 0.01891110011343777
# 0.025866650170156654
# 0.025866650170156654
# OneQuietNight(player=5)
# 0.02686665017015665
# DriveFerry(player=7, destination=10)
# 0.027866650170156652
# CharterFlight(player=7, destination=3)
# 0.02191110011343777
# DirectFlight(player=7, destination=34)
# 0.02291110011343777
# DirectFlight(player=7, destination=16)
# 0.016955550056718886
# 0.016955550056718886
# 0.016955550056718886
# 0.016955550056718886
# 0.016955550056718886
# DriveFerry(player=5, destination=45)
# 0.017955550056718884
# DirectFlight(player=5, destination=22)
# 0.012
# DriveFerry(player=5, destination=40)
# 0.013000000000000001
# DriveFerry(player=5, destination=26)
# 0.014
# 0.020955550056718883
# 0.020955550056718883
# 0.020955550056718883
# 0.020955550056718883
# DriveFerry(player=7, destination=9)
# 0.021955550056718884
# DriveFerry(player=7, destination=21)
# 0.022955550056718885
# DriveFerry(player=7, destination=11)
# 0.023955550056718886
# DriveFerry(player=7, destination=33)
# 0.024955550056718886
# 0.024955550056718886
# 0.03191110011343777
# 0.03191110011343777
# 0.03191110011343777
# DriveFerry(player=5, destination=1)
# 0.03291110011343777
# DirectFlight(player=5, destination=7)
# 0.026955550056718885
# DirectFlight(player=5, destination=6)
# 0.027955550056718886
# DirectFlight(player=5, destination=9)
# 0.028955550056718883
# 0.028955550056718883
# 0.028955550056718883
# 0.028955550056718883
# 0.028955550056718883
# DirectFlight(player=7, destination=45)
# 0.023
# DriveFerry(player=7, destination=14)
# 0.024
# DriveFerry(player=7, destination=42)
# 0.025
# DriveFerry(player=7, destination=47)
# 0.026000000000000002
# 0.03295555005671889
# 0.03991110011343777
# 0.03991110011343777
# 0.03991110011343777
# DriveFerry(player=5, destination=11)
# 0.040911100113437765
# DriveFerry(player=5, destination=33)
# 0.041911100113437766
# DriveFerry(player=5, destination=9)
# 0.04291110011343777
# DriveFerry(player=5, destination=33)
# 0.04391110011343777
# epidemic!!!
# 0.04391110011343777
# 0.04391110011343777
# 0.05086665017015665
# 0.05086665017015665
# outbreak
# -0.07413334982984335
# DirectFlight(player=7, destination=39)
# -0.08008889988656223
# DirectFlight(player=7, destination=25)
# -0.07908889988656223
# DriveFerry(player=7, destination=38)
# -0.07808889988656223
# DirectFlight(player=7, destination=31)
# -0.07708889988656223
# -0.07013334982984334
# -0.06604220794870866
# outbreak
# -0.19104220794870866
# -0.19104220794870866
# DirectFlight(player=5, destination=46)
# -0.19699775800542754
# DriveFerry(player=5, destination=18)
# -0.19599775800542754
# DirectFlight(player=5, destination=26)
# -0.19499775800542754
# DriveFerry(player=5, destination=1)
# -0.19399775800542754
# -0.19399775800542754
# -0.18704220794870866
# outbreak
# -0.3120422079487086
# -0.3120422079487086
# DriveFerry(player=7, destination=10)
# -0.3110422079487086
# DirectFlight(player=7, destination=15)
# -0.31413334982984337
# DriveFerry(player=7, destination=3)
# -0.31313334982984337
# DriveFerry(player=7, destination=15)
# -0.3121333498298433
# -0.3080422079487086
# -0.3080422079487086
# -0.3080422079487086
# -0.3080422079487086
# DriveFerry(player=5, destination=26)
# -0.3070422079487086
# DirectFlight(player=5, destination=40)
# -0.3060422079487087
# DirectFlight(player=5, destination=14)
# -0.31199775800542756
# DriveFerry(player=5, destination=21)
# -0.31099775800542756
# epidemic!!!
# -0.31099775800542756
# -0.31099775800542756
# -0.31099775800542756
# -0.31099775800542756
# outbreak
# -0.43599775800542756
# reward:  tensor([-0.4360])
# steps:  46
# illegal actions:  10
# cures:  {3: False, 4: False, 1: False, 2: False}
# outbreaks:  4
# GovernmentGrant(player=5, target_city=32)
# 0.01204669193785357
# DriveFerry(player=5, destination=10)
# 0.01304669193785357
# DriveFerry(player=5, destination=38)
# 0.01404669193785357
# DirectFlight(player=5, destination=18)
# 0.01504669193785357
# DriveFerry(player=5, destination=46)
# 0.01604669193785357
# 0.01604669193785357
# 0.023002241994572455
# 0.023002241994572455
# 0.023002241994572455
# DriveFerry(player=7, destination=48)
# 0.024002241994572453
# DirectFlight(player=7, destination=28)
# 0.025002241994572454
# DriveFerry(player=7, destination=23)
# 0.026002241994572454
# DriveFerry(player=7, destination=39)
# 0.027002241994572455
# epidemic!!!
# 0.027002241994572455
# 0.027002241994572455
# 0.027002241994572455
# OneQuietNight(player=7)
# 0.028002241994572456
# DriveFerry(player=5, destination=11)
# 0.029002241994572454
# DirectFlight(player=5, destination=39)
# 0.030002241994572455
# DriveFerry(player=5, destination=23)
# 0.031002241994572455
# DriveFerry(player=5, destination=28)
# 0.03200224199457245
# 0.03200224199457245
# 0.03609338387570714
# 0.03609338387570714
# 0.03609338387570714
# DirectFlight(player=7, destination=36)
# 0.033002241994572454
# DriveFerry(player=7, destination=24)
# 0.034002241994572455
# DriveFerry(player=7, destination=12)
# 0.035002241994572456
# DriveFerry(player=7, destination=36)
# 0.036002241994572456
# 0.036002241994572456
# 0.036002241994572456
# 0.036002241994572456
# 0.036002241994572456
# DriveFerry(player=5, destination=6)
# 0.03700224199457246
# DriveFerry(player=5, destination=40)
# 0.03800224199457246
# DriveFerry(player=5, destination=22)
# 0.03900224199457246
# TreatDisease(city=22, target_virus=3)
# 0.04000224199457245
# 0.04695779205129134
# 0.04695779205129134
# outbreak
# -0.07804220794870867
# outbreak
# outbreak
# outbreak
# -0.32804220794870864
# DirectFlight(player=7, destination=33)
# -0.32704220794870864
# DirectFlight(player=7, destination=16)
# -0.32604220794870864
# TreatDisease(city=16, target_virus=2)
# -0.32504220794870864
# DirectFlight(player=7, destination=30)
# -0.3309977580054275
# -0.3309977580054275
# ResilientPopulation(player=7, discard_city=4)
# -0.3299977580054275
# outbreak
# -0.4549977580054275
# -0.4549977580054275
# DriveFerry(player=5, destination=40)
# -0.4539977580054275
# DirectFlight(player=5, destination=32)
# -0.4529977580054275
# DirectFlight(player=5, destination=26)
# -0.4560888998865622
# DirectFlight(player=5, destination=19)
# -0.4620444499432811
# -0.4620444499432811
# -0.4550888998865622
# -0.4550888998865622
# -0.4550888998865622
# DirectFlight(player=7, destination=40)
# -0.4540888998865622
# DirectFlight(player=7, destination=31)
# -0.4530888998865622
# DriveFerry(player=7, destination=34)
# -0.4520888998865622
# DriveFerry(player=7, destination=26)
# -0.4510888998865622
# -0.4510888998865622
# -0.4441333498298433
# -0.4441333498298433
# outbreak
# -0.5691333498298433
# DirectFlight(player=5, destination=5)
# -0.5750888998865622
# DriveFerry(player=5, destination=41)
# -0.5740888998865622
# DirectFlight(player=5, destination=11)
# -0.5730888998865622
# DriveFerry(player=5, destination=9)
# -0.5720888998865622
# -0.5651333498298433
# -0.5651333498298433
# -0.5651333498298433
# -0.5651333498298433
# DriveFerry(player=7, destination=34)
# -0.5641333498298433
# DriveFerry(player=7, destination=24)
# -0.5631333498298433
# TreatDisease(city=24, target_virus=1)
# -0.5621333498298433
# DriveFerry(player=7, destination=34)
# -0.5611333498298433
# -0.5611333498298433
# -0.5611333498298433
# -0.5611333498298433
# -0.5611333498298433
# DriveFerry(player=5, destination=11)
# -0.5601333498298433
# DriveFerry(player=5, destination=21)
# -0.5591333498298433
# DirectFlight(player=5, destination=42)
# -0.5650888998865622
# DriveFerry(player=5, destination=47)
# -0.5640888998865622
# -0.5571333498298433
# epidemic!!!
# -0.5571333498298433
# -0.5571333498298433
# -0.5571333498298433
# DirectFlight(player=7, destination=25)
# -0.5630888998865622
# DriveFerry(player=7, destination=44)
# -0.5620888998865622
# DriveFerry(player=7, destination=27)
# -0.5610888998865622
# DirectFlight(player=7, destination=41)
# -0.5600888998865622
# -0.5531333498298433
# -0.5531333498298433
# -0.5531333498298433
# -0.5531333498298433
# DirectFlight(player=5, destination=46)
# -0.5521333498298433
# DirectFlight(player=5, destination=6)
# -0.5580888998865623
# DriveFerry(player=5, destination=29)
# -0.5570888998865622
# DriveFerry(player=5, destination=28)
# -0.5560888998865623
# -0.5491333498298434
# -0.5450422079487087
# -0.5450422079487087
# -0.5450422079487087
# DirectFlight(player=7, destination=44)
# -0.5440422079487086
# DriveFerry(player=7, destination=27)
# -0.5430422079487087
# DriveFerry(player=7, destination=44)
# -0.5420422079487086
# DirectFlight(player=7, destination=3)
# -0.5479977580054276
# -0.5479977580054276
# -0.5410422079487087
# -0.5410422079487087
# -0.5410422079487087
# DriveFerry(player=5, destination=6)
# -0.5400422079487086
# DriveFerry(player=5, destination=28)
# -0.5390422079487087
# DirectFlight(player=5, destination=43)
# -0.5421333498298433
# DriveFerry(player=5, destination=15)
# -0.5411333498298434
# -0.5370422079487087
# -0.5370422079487087
# Airlift(player=5, target_player=7, destination=38)
# -0.5360422079487086
# -0.5360422079487086
# CharterFlight(player=7, destination=16)
# -0.5350422079487087
# DriveFerry(player=7, destination=9)
# -0.5340422079487086
# DirectFlight(player=7, destination=37)
# -0.5399977580054276
# DirectFlight(player=7, destination=7)
# -0.5389977580054275
# -0.5389977580054275
# -0.5389977580054275
# -0.5389977580054275
# outbreak
# outbreak
# outbreak
# outbreak
# outbreak
# outbreak
# -1.1639977580054275
# reward:  tensor([-1.1640])
# steps:  68
# illegal actions:  13
# cures:  {3: False, 4: False, 1: False, 2: False}
# outbreaks:  10
# GovernmentGrant(player=5, target_city=44)
# 0.019002241994572455
# DriveFerry(player=5, destination=10)
# 0.020002241994572456
# CharterFlight(player=5, destination=40)
# 0.01404669193785357
# DirectFlight(player=5, destination=17)
# 0.01504669193785357
# DirectFlight(player=5, destination=38)
# 0.01604669193785357
# 0.01604669193785357
# 0.01604669193785357
# 0.01604669193785357
# 0.01604669193785357
# DirectFlight(player=7, destination=31)
# 0.012955550056718885
# DirectFlight(player=7, destination=48)
# 0.007
# DriveFerry(player=7, destination=29)
# 0.008
# DriveFerry(player=7, destination=28)
# 0.009000000000000001
# epidemic!!!
# 0.009000000000000001
# 0.009000000000000001
# 0.015955550056718885
# outbreak
# -0.10904444994328111
# outbreak
# -0.2340444499432811
# DriveFerry(player=5, destination=27)
# -0.2330444499432811
# DriveFerry(player=5, destination=38)
# -0.2320444499432811
# DriveFerry(player=5, destination=25)
# -0.2310444499432811
# DirectFlight(player=5, destination=29)
# -0.2300444499432811
# -0.2300444499432811
# -0.2300444499432811
# -0.2300444499432811
# outbreak
# -0.3550444499432811
# DriveFerry(player=7, destination=29)
# -0.3540444499432811
# DriveFerry(player=7, destination=2)
# -0.3530444499432811
# ShuttleFlight(player=7, destination=44)
# -0.3520444499432811
# DirectFlight(player=7, destination=9)
# -0.358
# -0.358
# -0.3510444499432811
# -0.3510444499432811
# -0.3510444499432811
# DirectFlight(player=5, destination=13)
# -0.3500444499432811
# DriveFerry(player=5, destination=14)
# -0.3490444499432811
# DriveFerry(player=5, destination=21)
# -0.3480444499432811
# DriveFerry(player=5, destination=14)
# -0.3470444499432811
# -0.3400888998865622
# -0.3400888998865622
# -0.3400888998865622
# -0.3400888998865622
# DriveFerry(player=7, destination=4)
# -0.3390888998865622
# DriveFerry(player=7, destination=21)
# -0.3380888998865622
# DriveFerry(player=7, destination=14)
# -0.3370888998865622
# DriveFerry(player=7, destination=21)
# -0.3360888998865622
# -0.3360888998865622
# -0.3291333498298433
# -0.3291333498298433
# -0.3291333498298433
# DirectFlight(player=5, destination=39)
# -0.3350888998865622
# DriveFerry(player=5, destination=23)
# -0.3340888998865622
# DirectFlight(player=5, destination=40)
# -0.3330888998865622
# DriveFerry(player=5, destination=22)
# -0.3320888998865622
# -0.3320888998865622
# Forecast(player=5)
# -0.3310888998865622
# ChooseCard(player=5, card=42)
# -0.3300888998865622
# ChooseCard(player=5, card=24)
# -0.3290888998865622
# ChooseCard(player=5, card=30)
# -0.3280888998865622
# ChooseCard(player=5, card=46)
# -0.3270888998865622
# ChooseCard(player=5, card=32)
# -0.3260888998865622
# ChooseCard(player=5, card=44)
# -0.3181333498298433
# -0.3181333498298433
# -0.3181333498298433
# DirectFlight(player=7, destination=42)
# -0.31713334982984337
# DirectFlight(player=7, destination=28)
# -0.32308889988656225
# DriveFerry(player=7, destination=10)
# -0.32208889988656225
# DirectFlight(player=7, destination=18)
# -0.32804444994328114
# -0.32108889988656225
# epidemic!!!
# -0.32108889988656225
# -0.32108889988656225
# -0.32108889988656225
# DirectFlight(player=5, destination=11)
# -0.32704444994328113
# DirectFlight(player=5, destination=15)
# -0.32604444994328113
# DriveFerry(player=5, destination=43)
# -0.32504444994328113
# DriveFerry(player=5, destination=12)
# -0.32404444994328113
# -0.32404444994328113
# -0.32404444994328113
# ResilientPopulation(player=5, discard_city=15)
# -0.32304444994328113
# -0.32304444994328113
# DriveFerry(player=7, destination=33)
# -0.32204444994328113
# DirectFlight(player=7, destination=23)
# -0.32104444994328113
# DirectFlight(player=7, destination=12)
# -0.327
# TreatDisease(city=12, target_virus=1)
# -0.326
# -0.326
# -0.3190444499432811
# -0.3190444499432811
# -0.3190444499432811
# DriveFerry(player=5, destination=24)
# -0.3180444499432811
# DriveFerry(player=5, destination=36)
# -0.3170444499432811
# DriveFerry(player=5, destination=12)
# -0.3160444499432811
# DriveFerry(player=5, destination=24)
# -0.3150444499432811
# -0.3150444499432811
# -0.30808889988656224
# -0.30808889988656224
# -0.30808889988656224
# DriveFerry(player=7, destination=43)
# -0.30708889988656224
# DirectFlight(player=7, destination=46)
# -0.3130444499432811
# DriveFerry(player=7, destination=32)
# -0.3120444499432811
# DirectFlight(player=7, destination=41)
# -0.3110444499432811
# -0.30408889988656224
# -0.30408889988656224
# -0.30408889988656224
# -0.30408889988656224
# DriveFerry(player=5, destination=12)
# -0.30308889988656224
# DirectFlight(player=5, destination=6)
# -0.3090444499432811
# DirectFlight(player=5, destination=35)
# -0.3080444499432811
# TreatDisease(city=35, target_virus=2)
# -0.3070444499432811
# -0.3070444499432811
# -0.3070444499432811
# -0.3070444499432811
# -0.3070444499432811
# DriveFerry(player=7, destination=42)
# -0.3060444499432811
# DirectFlight(player=7, destination=25)
# -0.3050444499432811
# TreatDisease(city=25, target_virus=3)
# -0.3040444499432811
# DirectFlight(player=7, destination=36)
# -0.31
# -0.31
# -0.3030444499432811
# -0.3030444499432811
# -0.3030444499432811
# DriveFerry(player=5, destination=47)
# -0.3020444499432811
# DirectFlight(player=5, destination=14)
# -0.3010444499432811
# DirectFlight(player=5, destination=26)
# -0.3000444499432811
# DirectFlight(player=5, destination=22)
# -0.2990444499432811
# -0.2990444499432811
# -0.2990444499432811
# -0.2990444499432811
# -0.2990444499432811
# DirectFlight(player=7, destination=47)
# -0.2980444499432811
# DirectFlight(player=7, destination=37)
# -0.2970444499432811
# DriveFerry(player=7, destination=8)
# -0.2960444499432811
# TreatDisease(city=8, target_virus=4)
# -0.2950444499432811
# epidemic!!!
# -0.2950444499432811
# reward:  tensor([-0.2950])
# steps:  73
# illegal actions:  17
# cures:  {3: False, 4: False, 1: False, 2: False}
# outbreaks:  3
# GovernmentGrant(player=7, target_city=43)
# 0.01491110011343777
# ResilientPopulation(player=7, discard_city=11)
# 0.01591110011343777
# DirectFlight(player=5, destination=18)
# 0.009955550056718884
# DriveFerry(player=5, destination=33)
# 0.010955550056718884
# CharterFlight(player=5, destination=17)
# 0.011955550056718885
# DirectFlight(player=5, destination=42)
# 0.006
# 0.006
# 0.006
# 0.006
# 0.006
# ShuttleFlight(player=7, destination=43)
# 0.007
# ShuttleFlight(player=7, destination=2)
# 0.008
# DriveFerry(player=7, destination=10)
# 0.009000000000000001
# DriveFerry(player=7, destination=28)
# 0.01
# 0.01
# epidemic!!!
# 0.01
# 0.01
# 0.01
# DriveFerry(player=5, destination=41)
# 0.011
# DirectFlight(player=5, destination=43)
# 0.012
# DirectFlight(player=5, destination=27)
# 0.013000000000000001
# DriveFerry(player=5, destination=45)
# 0.014
# 0.020955550056718883
# 0.020955550056718883
# 0.020955550056718883
# 0.020955550056718883
# DirectFlight(player=7, destination=23)
# 0.021955550056718884
# DirectFlight(player=7, destination=34)
# 0.022955550056718885
# DriveFerry(player=7, destination=31)
# 0.023955550056718886
# DriveFerry(player=7, destination=10)
# 0.024955550056718886
# 0.024955550056718886
# 0.03191110011343777
# 0.03191110011343777
# 0.03191110011343777
# DriveFerry(player=5, destination=27)
# 0.03291110011343777
# DirectFlight(player=5, destination=35)
# 0.03391110011343777
# DriveFerry(player=5, destination=45)
# 0.034911100113437774
# DriveFerry(player=5, destination=35)
# 0.03591110011343777
# 0.04000224199457245
# 0.04000224199457245
# 0.04000224199457245
# 0.04000224199457245
# TreatDisease(city=10, target_virus=1)
# 0.041002241994572454
# DriveFerry(player=7, destination=31)
# 0.042002241994572455
# DirectFlight(player=7, destination=30)
# 0.03604669193785357
# DirectFlight(player=7, destination=37)
# 0.03704669193785357
# 0.03704669193785357
# 0.03704669193785357
# 0.03704669193785357
# 0.03704669193785357
# DirectFlight(player=5, destination=21)
# 0.03395555005671888
# DirectFlight(player=5, destination=32)
# 0.028
# DirectFlight(player=5, destination=39)
# 0.029
# DriveFerry(player=5, destination=23)
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# DirectFlight(player=7, destination=7)
# 0.031
# DirectFlight(player=7, destination=38)
# 0.032
# DriveFerry(player=7, destination=25)
# 0.033
# DirectFlight(player=7, destination=3)
# 0.034
# 0.034
# 0.034
# 0.034
# 0.034
# DirectFlight(player=5, destination=16)
# 0.035
# DirectFlight(player=5, destination=2)
# 0.036000000000000004
# DirectFlight(player=5, destination=11)
# 0.037
# DriveFerry(player=5, destination=9)
# 0.038
# 0.038
# 0.038
# 0.038
# 0.038
# DriveFerry(player=7, destination=15)
# 0.039
# DirectFlight(player=7, destination=29)
# 0.04
# TreatDisease(city=29, target_virus=3)
# 0.041
# DriveFerry(player=7, destination=2)
# 0.042
# epidemic!!!
# 0.042
# 0.042
# 0.042
# 0.042
# 0.042
# DirectFlight(player=5, destination=40)
# 0.043000000000000003
# DriveFerry(player=5, destination=22)
# 0.044
# DriveFerry(player=5, destination=20)
# 0.045
# DirectFlight(player=5, destination=14)
# 0.046
# 0.046
# 0.046
# 0.046
# outbreak
# -0.079
# DriveFerry(player=7, destination=48)
# -0.078
# DriveFerry(player=7, destination=29)
# -0.077
# DriveFerry(player=7, destination=48)
# -0.076
# DirectFlight(player=7, destination=24)
# -0.075
# -0.06804444994328111
# -0.06804444994328111
# -0.06804444994328111
# -0.06804444994328111
# DriveFerry(player=5, destination=42)
# -0.06704444994328111
# DriveFerry(player=5, destination=5)
# -0.06604444994328111
# TreatDisease(city=5, target_virus=2)
# -0.06504444994328112
# DirectFlight(player=5, destination=44)
# -0.06404444994328112
# -0.06404444994328112
# -0.05708889988656224
# -0.05708889988656224
# outbreak
# -0.18208889988656224
# DirectFlight(player=7, destination=13)
# -0.18804444994328112
# DriveFerry(player=7, destination=27)
# -0.18704444994328112
# DriveFerry(player=7, destination=13)
# -0.18604444994328112
# DriveFerry(player=7, destination=14)
# -0.18504444994328112
# -0.17808889988656224
# -0.17808889988656224
# Forecast(player=7)
# -0.17708889988656223
# ChooseCard(player=7, card=12)
# -0.17608889988656223
# ChooseCard(player=7, card=44)
# -0.17508889988656223
# ChooseCard(player=7, card=48)
# -0.17408889988656223
# ChooseCard(player=7, card=38)
# -0.17308889988656223
# ChooseCard(player=7, card=7)
# -0.17208889988656223
# ChooseCard(player=7, card=10)
# -0.17108889988656223
# -0.17108889988656223
# DirectFlight(player=5, destination=25)
# -0.1770444499432811
# DriveFerry(player=5, destination=44)
# -0.1760444499432811
# DriveFerry(player=5, destination=25)
# -0.1750444499432811
# DirectFlight(player=5, destination=17)
# -0.1740444499432811
# -0.1740444499432811
# -0.1740444499432811
# -0.1740444499432811
# -0.1740444499432811
# DriveFerry(player=7, destination=21)
# -0.1730444499432811
# DriveFerry(player=7, destination=4)
# -0.1720444499432811
# DriveFerry(player=7, destination=21)
# -0.1710444499432811
# DirectFlight(player=7, destination=10)
# -0.177
# -0.177
# -0.1700444499432811
# -0.1700444499432811
# -0.1700444499432811
# DriveFerry(player=5, destination=20)
# -0.1690444499432811
# DriveFerry(player=5, destination=19)
# -0.1680444499432811
# DriveFerry(player=5, destination=17)
# -0.1670444499432811
# DirectFlight(player=5, destination=41)
# -0.1660444499432811
# -0.1660444499432811
# Airlift(player=5, target_player=5, destination=32)
# epidemic!!!
# outbreak
# outbreak
# outbreak
# outbreak
# outbreak
# -0.5400444499432812
# -0.5400444499432812
# -0.5400444499432812
# -0.5400444499432812
# DriveFerry(player=7, destination=31)
# -0.5390444499432812
# CharterFlight(player=7, destination=33)
# -0.545
# DriveFerry(player=7, destination=18)
# -0.544
# DriveFerry(player=7, destination=46)
# -0.543
# -0.543
# -0.5360444499432812
# -0.5360444499432812
# -0.5360444499432812
# -0.5360444499432812
# DriveFerry(player=5, destination=43)
# -0.5350444499432812
# DriveFerry(player=5, destination=12)
# -0.5340444499432812
# CharterFlight(player=5, destination=45)
# -0.5330444499432812
# DirectFlight(player=5, destination=6)
# -0.5320444499432812
# -0.5320444499432812
# OneQuietNight(player=5)
# -0.5310444499432811
# -0.5310444499432811
# DriveFerry(player=7, destination=32)
# -0.5300444499432811
# DriveFerry(player=7, destination=15)
# -0.5290444499432811
# DirectFlight(player=7, destination=28)
# -0.535
# DriveFerry(player=7, destination=25)
# -0.534
# -0.5270444499432811
# -0.5200888998865623
# -0.5200888998865623
# -0.5200888998865623
# -0.5200888998865623
# DriveFerry(player=5, destination=7)
# -0.5190888998865623
# DriveFerry(player=5, destination=6)
# -0.5180888998865623
# DirectFlight(player=5, destination=19)
# -0.5170888998865623
# DriveFerry(player=5, destination=20)
# -0.5160888998865623
# -0.5160888998865623
# epidemic!!!
# outbreak
# outbreak
# outbreak
# outbreak
# outbreak
# outbreak
# outbreak
# -1.2660888998865623
# reward:  tensor([-1.2661])
# steps:  95
# illegal actions:  20
# cures:  {3: False, 4: False, 1: False, 2: False}
# outbreaks:  11
# DirectFlight(player=5, destination=7)
# 0.007955550056718885
# DirectFlight(player=5, destination=4)
# 0.008955550056718884
# DirectFlight(player=5, destination=32)
# 0.009955550056718884
# OneQuietNight(player=5)
# 0.010955550056718884
# DriveFerry(player=5, destination=43)
# 0.011955550056718885
# 0.011955550056718885
# 0.011955550056718885
# 0.011955550056718885
# DriveFerry(player=7, destination=10)
# 0.012955550056718885
# DirectFlight(player=7, destination=40)
# 0.007
# DriveFerry(player=7, destination=6)
# 0.008
# DriveFerry(player=7, destination=40)
# 0.009000000000000001
# 0.015955550056718885
# 0.02291110011343777
# 0.02291110011343777
# 0.02291110011343777
# DriveFerry(player=5, destination=32)
# 0.02391110011343777
# DirectFlight(player=5, destination=41)
# 0.024911100113437768
# DriveFerry(player=5, destination=5)
# 0.02591110011343777
# DriveFerry(player=5, destination=41)
# 0.02691110011343777
# epidemic!!!
# 0.02691110011343777
# 0.02691110011343777
# 0.02691110011343777
# 0.02691110011343777
# outbreak
# -0.09808889988656223
# DirectFlight(player=7, destination=8)
# -0.10404444994328112
# DriveFerry(player=7, destination=19)
# -0.10304444994328112
# DirectFlight(player=7, destination=5)
# -0.10204444994328112
# DirectFlight(player=7, destination=22)
# -0.108
# -0.108
# -0.10104444994328111
# -0.10104444994328111
# -0.10104444994328111
# DirectFlight(player=5, destination=3)
# -0.10004444994328111
# DriveFerry(player=5, destination=18)
# -0.09904444994328111
# DriveFerry(player=5, destination=3)
# -0.09804444994328111
# DriveFerry(player=5, destination=8)
# -0.09704444994328111
# -0.09704444994328111
# -0.09704444994328111
# outbreak
# -0.22204444994328112
# -0.22204444994328112
# DriveFerry(player=7, destination=19)
# -0.22104444994328112
# DriveFerry(player=7, destination=17)
# -0.22004444994328112
# DirectFlight(player=7, destination=14)
# -0.21904444994328112
# DriveFerry(player=7, destination=21)
# -0.21804444994328112
# -0.21804444994328112
# -0.21108889988656224
# -0.21108889988656224
# outbreak
# outbreak
# outbreak
# -0.4610888998865622
# DirectFlight(player=5, destination=31)
# -0.4600888998865622
# DriveFerry(player=5, destination=48)
# -0.4590888998865622
# DriveFerry(player=5, destination=29)
# -0.4580888998865622
# DriveFerry(player=5, destination=48)
# -0.4570888998865622
# -0.4501333498298433
# -0.4501333498298433
# outbreak
# outbreak
# outbreak
# -0.7001333498298433
# -0.7001333498298433
# DirectFlight(player=7, destination=35)
# -0.7060888998865622
# DirectFlight(player=7, destination=47)
# -0.7050888998865622
# DirectFlight(player=7, destination=21)
# -0.7110444499432811
# DriveFerry(player=7, destination=9)
# -0.7100444499432811
# -0.7100444499432811
# ResilientPopulation(player=7, discard_city=11)
# -0.7090444499432811
# outbreak
# outbreak
# -0.9590444499432811
# reward:  tensor([-0.9590])
# steps:  34
# illegal actions:  7
# cures:  {3: False, 4: False, 1: False, 2: False}
# outbreaks:  8
# OneQuietNight(player=5)
# 0.001
# DriveFerry(player=5, destination=10)
# 0.002
# DriveFerry(player=5, destination=38)
# 0.003
# DirectFlight(player=5, destination=28)
# 0.004
# DriveFerry(player=5, destination=10)
# 0.005
# Forecast(player=5)
# 0.006
# ChooseCard(player=5, card=24)
# 0.007
# ChooseCard(player=5, card=4)
# 0.008
# ChooseCard(player=5, card=43)
# 0.009000000000000001
# ChooseCard(player=5, card=29)
# 0.01
# ChooseCard(player=5, card=31)
# 0.011
# ChooseCard(player=5, card=5)
# 0.012
# 0.012
# 0.012
# DirectFlight(player=7, destination=43)
# 0.013000000000000001
# DirectFlight(player=7, destination=4)
# 0.014
# DriveFerry(player=7, destination=9)
# 0.015
# DriveFerry(player=7, destination=21)
# 0.016
# 0.022955550056718885
# 0.022955550056718885
# 0.022955550056718885
# 0.022955550056718885
# DriveFerry(player=5, destination=28)
# 0.023955550056718886
# DirectFlight(player=5, destination=31)
# 0.024955550056718886
# DriveFerry(player=5, destination=10)
# 0.025955550056718884
# DriveFerry(player=5, destination=28)
# 0.026955550056718885
# epidemic!!!
# 0.026955550056718885
# 0.026955550056718885
# 0.026955550056718885
# 0.026955550056718885
# 0.026955550056718885
# DirectFlight(player=7, destination=23)
# 0.021
# DirectFlight(player=7, destination=37)
# 0.022
# DriveFerry(player=7, destination=18)
# 0.023
# DirectFlight(player=7, destination=40)
# 0.024
# 0.024
# 0.030955550056718885
# 0.030955550056718885
# 0.030955550056718885
# DirectFlight(player=5, destination=25)
# 0.031955550056718886
# DirectFlight(player=5, destination=1)
# 0.03295555005671889
# DriveFerry(player=5, destination=26)
# 0.03395555005671888
# DriveFerry(player=5, destination=34)
# 0.03495555005671888
# 0.03495555005671888
# GovernmentGrant(player=5, target_city=44)
# 0.03595555005671888
# 0.03595555005671888
# 0.03595555005671888
# DirectFlight(player=7, destination=14)
# 0.03
# DriveFerry(player=7, destination=45)
# 0.031
# DriveFerry(player=7, destination=14)
# 0.032
# DriveFerry(player=7, destination=4)
# 0.033
# 0.033
# 0.039955550056718886
# outbreak
# -0.08504444994328111
# -0.08504444994328111
# DriveFerry(player=5, destination=24)
# -0.08404444994328111
# DriveFerry(player=5, destination=34)
# -0.08304444994328111
# DriveFerry(player=5, destination=26)
# -0.08204444994328111
# DriveFerry(player=5, destination=1)
# -0.08104444994328111
# -0.07408889988656223
# -0.06713334982984334
# -0.06713334982984334
# outbreak
# -0.19213334982984334
# DirectFlight(player=7, destination=45)
# -0.19808889988656223
# DriveFerry(player=7, destination=27)
# -0.19708889988656222
# DriveFerry(player=7, destination=45)
# -0.19608889988656222
# DirectFlight(player=7, destination=7)
# -0.19508889988656222
# -0.19508889988656222
# -0.18813334982984334
# -0.18813334982984334
# outbreak
# -0.31313334982984337
# DriveFerry(player=5, destination=26)
# -0.3121333498298433
# DriveFerry(player=5, destination=24)
# -0.3111333498298433
# DriveFerry(player=5, destination=34)
# -0.31013334982984336
# DirectFlight(player=5, destination=27)
# -0.31608889988656225
# -0.31199775800542756
# -0.31199775800542756
# Airlift(player=5, target_player=7, destination=12)
# -0.31099775800542756
# -0.31099775800542756
# DriveFerry(player=7, destination=24)
# -0.30999775800542756
# DriveFerry(player=7, destination=12)
# -0.30899775800542756
# DriveFerry(player=7, destination=43)
# -0.30799775800542756
# DriveFerry(player=7, destination=32)
# -0.30699775800542756
# -0.3000422079487087
# -0.2930866578919898
# -0.2930866578919898
# -0.2930866578919898
# DriveFerry(player=5, destination=45)
# -0.2920866578919898
# DriveFerry(player=5, destination=14)
# -0.2910866578919898
# DriveFerry(player=5, destination=42)
# -0.2900866578919898
# CharterFlight(player=5, destination=5)
# -0.2890866578919898
# epidemic!!!
# -0.2890866578919898
# -0.2890866578919898
# -0.2890866578919898
# outbreak
# -0.4140866578919898
# outbreak
# -0.5390866578919897
# DirectFlight(player=7, destination=20)
# -0.5450422079487087
# DirectFlight(player=7, destination=26)
# -0.5509977580054275
# DriveFerry(player=7, destination=24)
# -0.5499977580054276
# DirectFlight(player=7, destination=36)
# -0.5489977580054275
# -0.5489977580054275
# -0.5420422079487086
# outbreak
# outbreak
# outbreak
# -0.7920422079487086
# outbreak
# -0.9170422079487086
# reward:  tensor([-0.9170])
# steps:  58
# illegal actions:  13
# cures:  {3: False, 4: False, 1: False, 2: False}
# outbreaks:  8
# Airlift(player=7, target_player=7, destination=20)
# 0.01491110011343777
# CharterFlight(player=5, destination=42)
# 0.008955550056718884
# DirectFlight(player=5, destination=35)
# 0.009955550056718884
# DirectFlight(player=5, destination=21)
# 0.010955550056718884
# DriveFerry(player=5, destination=4)
# 0.011955550056718885
# 0.011955550056718885
# 0.01891110011343777
# 0.01891110011343777
# 0.01891110011343777
# DriveFerry(player=7, destination=17)
# 0.019911100113437767
# CharterFlight(player=7, destination=19)
# 0.013955550056718884
# TreatDisease(city=19, target_virus=3)
# 0.014955550056718885
# DriveFerry(player=7, destination=8)
# 0.015955550056718885
# 0.02291110011343777
# 0.029866650170156654
# 0.029866650170156654
# 0.029866650170156654
# DriveFerry(player=5, destination=13)
# 0.030866650170156655
# DirectFlight(player=5, destination=28)
# 0.024911100113437768
# DriveFerry(player=5, destination=10)
# 0.02591110011343777
# CharterFlight(player=5, destination=13)
# 0.02691110011343777
# 0.02691110011343777
# 0.03386665017015665
# 0.03386665017015665
# 0.03386665017015665
# DirectFlight(player=7, destination=31)
# 0.027911100113437767
# DirectFlight(player=7, destination=26)
# 0.028911100113437768
# DriveFerry(player=7, destination=24)
# 0.02991110011343777
# DriveFerry(player=7, destination=12)
# 0.03091110011343777
# 0.03091110011343777
# epidemic!!!
# 0.03091110011343777
# 0.03091110011343777
# 0.03091110011343777
# DirectFlight(player=5, destination=25)
# 0.024955550056718886
# DirectFlight(player=5, destination=38)
# 0.025955550056718884
# DriveFerry(player=5, destination=10)
# 0.026955550056718885
# DriveFerry(player=5, destination=2)
# 0.027955550056718886
# 0.027955550056718886
# ResilientPopulation(player=5, discard_city=29)
# 0.028955550056718883
# 0.028955550056718883
# 0.028955550056718883
# DriveFerry(player=7, destination=43)
# 0.029955550056718884
# DirectFlight(player=7, destination=22)
# 0.024
# DriveFerry(player=7, destination=40)
# 0.025
# CharterFlight(player=7, destination=6)
# 0.026000000000000002
# 0.026000000000000002
# 0.026000000000000002
# 0.026000000000000002
# 0.026000000000000002
# DriveFerry(player=5, destination=48)
# 0.027
# DriveFerry(player=5, destination=34)
# 0.028
# DirectFlight(player=5, destination=47)
# 0.029
# DriveFerry(player=5, destination=35)
# 0.03
# 0.03
# 0.03
# 0.03
# 0.03
# DriveFerry(player=7, destination=7)
# 0.031
# TreatDisease(city=7, target_virus=3)
# 0.032
# DirectFlight(player=7, destination=37)
# 0.033
# DirectFlight(player=7, destination=4)
# 0.034
# 0.034
# 0.034
# Forecast(player=7)
# 0.035
# ChooseCard(player=7, card=43)
# 0.036000000000000004
# ChooseCard(player=7, card=6)
# 0.037
# ChooseCard(player=7, card=30)
# 0.038
# ChooseCard(player=7, card=2)
# 0.039
# ChooseCard(player=7, card=39)
# 0.04
# ChooseCard(player=7, card=8)
# 0.041
# 0.041
# DirectFlight(player=5, destination=12)
# 0.042
# DirectFlight(player=5, destination=6)
# 0.043000000000000003
# DriveFerry(player=5, destination=23)
# 0.044
# DriveFerry(player=5, destination=6)
# 0.045
# 0.045
# 0.045
# 0.045
# 0.045
# DriveFerry(player=7, destination=13)
# 0.046
# DirectFlight(player=7, destination=30)
# 0.047
# DirectFlight(player=7, destination=16)
# 0.048
# DriveFerry(player=7, destination=13)
# 0.049
# 0.049
# 0.049
# 0.049
# 0.049
# DriveFerry(player=5, destination=40)
# 0.05
# DirectFlight(player=5, destination=1)
# 0.051000000000000004
# DirectFlight(player=5, destination=5)
# 0.052000000000000005
# DriveFerry(player=5, destination=41)
# 0.053
# epidemic!!!
# 0.053
# 0.053
# 0.053
# 0.053
# 0.053
# DriveFerry(player=7, destination=4)
# 0.054
# DirectFlight(player=7, destination=15)
# 0.055
# DriveFerry(player=7, destination=1)
# 0.056
# DriveFerry(player=7, destination=26)
# 0.057
# 0.057
# 0.06395555005671888
# 0.06395555005671888
# 0.06395555005671888
# DirectFlight(player=5, destination=29)
# 0.06495555005671888
# DriveFerry(player=5, destination=2)
# 0.06595555005671888
# DirectFlight(player=5, destination=13)
# 0.06695555005671888
# DriveFerry(player=5, destination=27)
# 0.06795555005671888
# 0.06795555005671888
# 0.06795555005671888
# 0.06795555005671888
# 0.06795555005671888
# DirectFlight(player=7, destination=23)
# 0.06895555005671888
# DirectFlight(player=7, destination=14)
# 0.063
# DriveFerry(player=7, destination=4)
# 0.064
